# %%
import pandas as pd
data = pd.read_csv('C:/Users/laure/Projet_arbre/data/trees.csv')

# %%
non_desirees["ESPECES"].tolist()
# Out:
# ['acer negundo',
#  'acer platanoides',
#  'acer pseudoplatanus',
#  'acer saccharinum',
#  'aesculus',
#  'ailanthus altissima',
#  'albizzia julibrissin',
#  'betula',
#  'betula costata',
#  'betula davurica',
#  'betula jacquemontii',
#  'betula lenta',
#  'betula maximowicziana',
#  'betula pendula',
#  'betula pubescens',
#  'betula utilis',
#  'castanea',
#  'catalpa bignonioïdes',
#  'cryptomeria japonica',
#  'cupressus',
#  'cupressus cashmeriana',
#  'davidia involucrata',
#  'fagus sylvatica',
#  'fraxinus',
#  'ginko biloba',
#  'gleditsia triacanthos',
#  'juglans ailantifolia',
#  'juglans nigra',
#  'koelreuteria paniculata',
#  'laburnum anagyroïdes',
#  'liriodendron tulipifera',
#  'magnolia grandiflora',
#  'nerium oleander',
#  'olea',
#  'paulownia tomentosa',
#  'picea abies',
#  'platanus',
#  'platanus acerifolia',
#  'populus alba',
#  'prunus pissardi',
#  'pseudoplatanus',
#  'quercus alba',
#  'quercus bicolor',
#  'quercus macrocarpa',
# ...

# %%
data= data.drop(['EQUIPE','REMARQUES','COURRIER','ANNEEABATTAGE','ESSOUCHEMENT','DIAMETREARBRE','CAUSEABATTAGE'], axis=1)

# %%
data.describe()
# Out:
#        ELEM_POINT_ID   ADR_SECTEUR  ANNEEDEPLANTATION  IDENTIFIANTPLU
# count   31243.000000  31243.000000       30801.000000      610.000000
# mean    17583.259290      3.855392        1987.869744       87.890164
# std     10407.363433      1.699391          16.171869       60.548636
# min         1.000000      1.000000        1950.000000        2.000000
# 25%      8653.500000      2.000000        1975.000000       67.000000
# 50%     17356.000000      4.000000        1985.000000       70.000000
# 75%     26071.500000      5.000000        2001.000000       70.000000
# max     39121.000000      6.000000        2017.000000      358.000000

# %%
data.columns
# Out:
# Index(['ELEM_POINT_ID', 'CODE', 'NOM', 'GENRE', 'GENRE_DESC', 'CATEGORIE',
#        'CATEGORIE_DESC', 'SOUS_CATEGORIE', 'SOUS_CATEGORIE_DESC',
#        'CODE_PARENT', 'CODE_PARENT_DESC', 'ADR_SECTEUR', 'BIEN_REFERENCE',
#        'GENRE_BOTA', 'ESPECE', 'VARIETE', 'STADEDEDEVELOPPEMENT',
#        'ANNEEDEPLANTATION', 'RAISONDEPLANTATION', 'TRAITEMENTCHENILLES',
#        'IDENTIFIANTPLU', 'TYPEIMPLANTATIONPLU', 'INTITULEPROTECTIONPLU',
#        'COLLECTIVITE', 'GeoJSON'],
#       dtype='object')

# %%
print(data)
# Out:
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0              37993  ESP37969  ESP37969   VEG  VEGETATION     ESP01
# 1              37992  ESP37968  ESP37968   VEG  VEGETATION     ESP01
# 2              37991  ESP37967  ESP37967   VEG  VEGETATION     ESP01
# 3              37990  ESP37966  ESP37966   VEG  VEGETATION     ESP01
# 4              37989  ESP37965  ESP37965   VEG  VEGETATION     ESP01
# ...              ...       ...       ...   ...         ...       ...
# 31238           7598   ESP2513   ESP2513   VEG  VEGETATION     ESP01
# 31239           7596   ESP2512   ESP2512   VEG  VEGETATION     ESP01
# 31240           7594   ESP2511   ESP2511   VEG  VEGETATION     ESP01
# 31241             19   ESP1798   ESP1798   VEG  VEGETATION     ESP01
# 31242             17   ESP1797   ESP1797   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE        SOUS_CATEGORIE_DESC CODE_PARENT  \
# ...

# %%
# Out:
# ...
#   Created wheel for jupyter-latex-envs: filename=jupyter_latex_envs-1.4.6-py2.py3-none-any.whl size=963398 sha256=aab7e76a350c191983c405faa2bc5788186270a2e6acf28ae7680ca4971594e0
#   Stored in directory: c:\users\laure\appdata\local\pip\cache\wheels\4d\ba\f4\b8c0941055519ebc0f27e85bfe2bb223f1a59a3b8bfc5c7515
# ...
#   Created wheel for jupyter-nbextensions-configurator: filename=jupyter_nbextensions_configurator-0.4.1-py2.py3-none-any.whl size=465828 sha256=221b88813c4ef66ae3ca8d58de327ee7dc7e05377b6e27d17845ef86223f9400
#   Stored in directory: c:\users\laure\appdata\local\pip\cache\wheels\e3\3a\b3\a709b437602c3807f079f0c35ccba3e1adf9af6f2e6b0ebfea
# Successfully built jupyter-latex-envs jupyter-nbextensions-configurator
# ...
# Note: you may need to restart the kernel to use updated packages.
# [I 10:18:56 InstallContribNbextensionsApp] jupyter contrib nbextension install
# ...

# %%
import datetime
print(datetime.date.today().year)
# Out:
# 2021

# %%
data["AGE"] = datetime.date.today().year - data["ANNEEDEPLANTATION"]

# %%
data
# Out:
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0              37993  ESP37969  ESP37969   VEG  VEGETATION     ESP01
# 1              37992  ESP37968  ESP37968   VEG  VEGETATION     ESP01
# 2              37991  ESP37967  ESP37967   VEG  VEGETATION     ESP01
# 3              37990  ESP37966  ESP37966   VEG  VEGETATION     ESP01
# 4              37989  ESP37965  ESP37965   VEG  VEGETATION     ESP01
# ...              ...       ...       ...   ...         ...       ...
# 31238           7598   ESP2513   ESP2513   VEG  VEGETATION     ESP01
# 31239           7596   ESP2512   ESP2512   VEG  VEGETATION     ESP01
# 31240           7594   ESP2511   ESP2511   VEG  VEGETATION     ESP01
# 31241             19   ESP1798   ESP1798   VEG  VEGETATION     ESP01
# 31242             17   ESP1797   ESP1797   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE        SOUS_CATEGORIE_DESC CODE_PARENT  \
# ...

# %%
print(age)
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 31238    20.0
# 31239    20.0
# 31240    20.0
# 31241    20.0
# 31242    20.0
# Name: ANNEEDEPLANTATION, Length: 31243, dtype: float64

# %%
data = pd.concat([data,age],axis=1)

# %%
print (data)
# Out:
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0              37993  ESP37969  ESP37969   VEG  VEGETATION     ESP01
# 1              37992  ESP37968  ESP37968   VEG  VEGETATION     ESP01
# 2              37991  ESP37967  ESP37967   VEG  VEGETATION     ESP01
# 3              37990  ESP37966  ESP37966   VEG  VEGETATION     ESP01
# 4              37989  ESP37965  ESP37965   VEG  VEGETATION     ESP01
# ...              ...       ...       ...   ...         ...       ...
# 31238           7598   ESP2513   ESP2513   VEG  VEGETATION     ESP01
# 31239           7596   ESP2512   ESP2512   VEG  VEGETATION     ESP01
# 31240           7594   ESP2511   ESP2511   VEG  VEGETATION     ESP01
# 31241             19   ESP1798   ESP1798   VEG  VEGETATION     ESP01
# 31242             17   ESP1797   ESP1797   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE        SOUS_CATEGORIE_DESC CODE_PARENT  \
# ...

# %%
data['AGE'].mean()
# Out:
# 33.1302555111847

# %%
data= data.drop(['EQUIPE','REMARQUES','COURRIER','ANNEEABATTAGE','ESSOUCHEMENT','DIAMETREARBRE','CAUSEABATTAGE'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-777761814a63> in <module>
# ----> 1 data= data.drop(['EQUIPE','REMARQUES','COURRIER','ANNEEABATTAGE','ESSOUCHEMENT','DIAMETREARBRE','CAUSEABATTAGE'], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
data.shape
# Out:
# (31243, 26)

# %%
data
# Out:
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0              37993  ESP37969  ESP37969   VEG  VEGETATION     ESP01
# 1              37992  ESP37968  ESP37968   VEG  VEGETATION     ESP01
# 2              37991  ESP37967  ESP37967   VEG  VEGETATION     ESP01
# 3              37990  ESP37966  ESP37966   VEG  VEGETATION     ESP01
# 4              37989  ESP37965  ESP37965   VEG  VEGETATION     ESP01
# ...              ...       ...       ...   ...         ...       ...
# 31238           7598   ESP2513   ESP2513   VEG  VEGETATION     ESP01
# 31239           7596   ESP2512   ESP2512   VEG  VEGETATION     ESP01
# 31240           7594   ESP2511   ESP2511   VEG  VEGETATION     ESP01
# 31241             19   ESP1798   ESP1798   VEG  VEGETATION     ESP01
# 31242             17   ESP1797   ESP1797   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE        SOUS_CATEGORIE_DESC CODE_PARENT  \
# ...

# %%
data.columns
# Out:
# Index(['ELEM_POINT_ID', 'CODE', 'NOM', 'GENRE', 'GENRE_DESC', 'CATEGORIE',
#        'CATEGORIE_DESC', 'SOUS_CATEGORIE', 'SOUS_CATEGORIE_DESC',
#        'CODE_PARENT', 'CODE_PARENT_DESC', 'ADR_SECTEUR', 'BIEN_REFERENCE',
#        'GENRE_BOTA', 'ESPECE', 'VARIETE', 'STADEDEDEVELOPPEMENT',
#        'ANNEEDEPLANTATION', 'RAISONDEPLANTATION', 'TRAITEMENTCHENILLES',
#        'IDENTIFIANTPLU', 'TYPEIMPLANTATIONPLU', 'INTITULEPROTECTIONPLU',
#        'COLLECTIVITE', 'GeoJSON', 'ANNEEDEPLANTATION'],
#       dtype='object')

# %%
data data['GENRE_BOTA'].str.lower() + " " + data['ESPECE'].str.lower()
# Out:
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#                ...
# 31238    fraxinus oxycarpa
# 31239    fraxinus oxycarpa
# 31240    fraxinus oxycarpa
# 31241    fraxinus oxycarpa
# 31242    fraxinus oxycarpa
# Length: 31243, dtype: object

# %%
print(pd.concat(data['GENRE_BOTA'],' ',data['ESPECE']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-7e76d8cec142> in <module>
# ----> 1 print(pd.concat(data['GENRE_BOTA'],' ',data['ESPECE']))
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     307     ):
#     308         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
# --> 309             raise TypeError(
#     310                 "first argument must be an iterable of pandas "
# ...

# %%
data = concat(data['GENRE_BOTA'],' ',data['ESPECE'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-3f82a0eee249> in <module>
# ----> 1 genre_espece = concat(data['GENRE_BOTA'],' ',data['ESPECE'])
#
# NameError: name 'concat' is not defined

# %%
data['GENRE_ESPECE']
# Out:
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#                ...
# 31238    fraxinus oxycarpa
# 31239    fraxinus oxycarpa
# 31240    fraxinus oxycarpa
# 31241    fraxinus oxycarpa
# 31242    fraxinus oxycarpa
# Name: GENRE_ESPECE, Length: 31243, dtype: object

# %%
data["GENRE_ESPECE"] = data['GENRE_BOTA'] + " " +data['ESPECE']

# %%
print('especes désirees :', sum(list(data[~data.GENRE_ESPECE.isin(non_desirees["ESPECES"].tolist())].GENRE_ESPECE.value_counts())))
print('especes non désirees :',sum(list(data[data.GENRE_ESPECE.isin(non_desirees["ESPECES"].tolist())].GENRE_ESPECE.value_counts())))
# Out:
# especes désirees : 18052
# especes non désirees : 11001

# %%
d = data.GENRE_ESPECE.value_counts()

# %%
d[10]
# Out:
# 567

# %%
pd.set_option("max_rows", None)

# %%
data.groupby(["GENRE_BOTA","ESPECE"]).count()
# Out:
#                                   ELEM_POINT_ID  CODE   NOM  GENRE  \
# GENRE_BOTA      ESPECE
# Abies           concolor                      5     5     5      5
#                 koreana                       1     1     1      1
#                 nordmaniana                  20    20    20     20
#                 pinsapo                       2     2     2      2
# Acer            buergerianum                 20    20    20     20
#                 campestre                   845   845   845    845
#                 capillipes                   15    15    15     15
#                 cappadocicum                198   198   198    198
#                 carpinifolia                  2     2     2      2
#                 davidii                       6     6     6      6
#                 freemanii                    52    52    52     52
#                 ginnala                      49    49    49     49
#                 griseum                       5     5     5      5
# ...

# %%
import folium

# %%
data.GeoJSON.str[(data.GeoJSON.str.index("coordinates"))]
# Out:
# 0        {"type":"P
# 1        {"type":"P
# 2        {"type":"P
# 3        {"type":"P
# 4        {"type":"P
#             ...
# 31238    {"type":"P
# 31239    {"type":"P
# 31240    {"type":"P
# 31241    {"type":"P
# 31242    {"type":"P
# Name: GeoJSON, Length: 31243, dtype: object

# %%
(data.GeoJSON.str.index("coordinates"))
# Out:
# 0        17
# 1        17
# 2        17
# 3        17
# 4        17
#          ..
# 31238    17
# 31239    17
# 31240    17
# 31241    17
# 31242    17
# Name: GeoJSON, Length: 31243, dtype: int64

# %%
(data.GeoJSON.str[data.GeoJSON.str.index("coordinates"):35])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 31238   NaN
# 31239   NaN
# 31240   NaN
# 31241   NaN
# 31242   NaN
# Name: GeoJSON, Length: 31243, dtype: float64

# %%
[i[i.index("coordinates")+13:len(i)-1] for i in data.GeoJSON]
# Out:
# ['[5.76034690089422,45.1543159441061]',
#  '[5.75982646464411,45.154046459904]',
#  '[5.75998073144869,45.1540202490699]',
#  '[5.76005703012677,45.1538601663191]',
#  '[5.76002027929244,45.1539221005346]',
#  '[5.75964922725342,45.1539021290266]',
#  '[5.75933241321141,45.1538061453373]',
#  '[5.75941985297356,45.153853839904]',
#  '[5.75950370414507,45.1536855428431]',
#  '[5.75955022968702,45.1538265990103]',
#  '[5.75957503510904,45.1537994932937]',
#  '[5.75948661745818,45.153920106268]',
#  '[5.75940731171848,45.1539706155293]',
#  '[5.70993030033263,45.2011114628248]',
#  '[5.70989486117473,45.2011851481893]',
#  '[5.70986376680713,45.2012538742983]',
#  '[5.70982802138637,45.2013210915823]',
#  '[5.7096808747068,45.2016819564332]',
#  '[5.70964698422622,45.2017442645365]',
#  '[5.70962434554891,45.2018147990159]',
#  '[5.70958109682952,45.201879739747]',
#  '[5.70956561545497,45.2019411122765]',
#  '[5.709530753269,45.2020049500504]',
# ...

# %%
print("[" + ','.join(data['GeoJSON'].tolist()) + "]")
# Out:
# [{"type":"Point","coordinates":[5.76034690089422,45.1543159441061]},{"type":"Point","coordinates":[5.75982646464411,45.154046459904]},{"type":"Point","coordinates":[5.75998073144869,45.1540202490699]},{"type":"Point","coordinates":[5.76005703012677,45.1538601663191]},{"type":"Point","coordinates":[5.76002027929244,45.1539221005346]},{"type":"Point","coordinates":[5.75964922725342,45.1539021290266]},{"type":"Point","coordinates":[5.75933241321141,45.1538061453373]},{"type":"Point","coordinates":[5.75941985297356,45.153853839904]},{"type":"Point","coordinates":[5.75950370414507,45.1536855428431]},{"type":"Point","coordinates":[5.75955022968702,45.1538265990103]},{"type":"Point","coordinates":[5.75957503510904,45.1537994932937]},{"type":"Point","coordinates":[5.75948661745818,45.153920106268]},{"type":"Point","coordinates":[5.75940731171848,45.1539706155293]},{"type":"Point","coordinates":[5.70993030033263,45.2011114628248]},{"type":"Point","coordinates":[5.70989486117473,45.20118514818
# ...

# %%
import folium

# %%
c= folium.Map(location=[45.1666700, 5.7166700],zoom_start=20)
folium.Marker([45.1666700,  5.7166700]).add_to(c)
folium.Marker([5.70859132563791,45.2040396058819]).add_to(c)
folium.Marker([5.70913733057587,45.202838885133]).add_to(c)
c.save('maCarte.html')

# %%
[i[i.index("coordinates")+13:len(i)-1] for i in data.GeoJSON][0]
# Out:
# '[5.76034690089422,45.1543159441061]'
